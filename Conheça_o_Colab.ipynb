# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro4Albuquerque/am-t4-s1a2026t2/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introdução a Python

# %%
a=2
b=3
print('A soma = ', a+b)

# %% [markdown]
# ##Segunda Camada

# %%
c=4
d=5
print('a multiplicação e: ', c*d)
# Out:
# a multiplicação e:  20

# %% [markdown]
# ##Bliblioteca a Funções de Pythom

# %%
import math

def equacao2grau(a, b, c):
  delta = b**2 - 4*a*c

  if (delta < 0 ):
    return 'numero sem raiz', delta

  x1 = (-b + math.sqrt(delta))/ (2*a)
  x2 = (-b - math.sqrt(delta))/ (2*a)

  return x1 , x2

# %% [markdown]
# ###Teste e Função Matematica

# %%
eq = equacao2grau(1, -3, 2)
print(eq)

# %%
import random

for i in range(5):
  a = random.randint(-5, 5)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)

  eq += equacao2grau(a, b, c)

# %%
for i in range(12):
  if(i % 2 == 0 ):
    if (eq[i] != 'numero sem raiz'):
      print('x1: [',eq[i],']')
  else:
    if (eq[i] != 'numero sem raiz'):
        print('X2: [', eq[i], ']\n')

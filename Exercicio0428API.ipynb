# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro4Albuquerque/am-t4-s1a2026t2/blob/main/Exercicio0428API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import List
import requests
import pandas as pd

API_KEY = 'YF91FPXACQJ396DA'
EMPRESAS = ['NFLX', 'AAPL' ,'GOOGL', 'AMZL', 'MSFT']
list_emp=[]

for simbolo in EMPRESAS:
  print(f'Extraindo dados da empresa {simbolo}')
url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={simbolo}&apikey={API_KEY}'
r = requests.get(url)
base = r.json()

if 'Global Quote' in base.keys():
  base_alpha = pd.DataFrame.from_dict([base['Global Quote']])
  list_emp.append(base_alpha)
# Out:
# Extraindo dados da empresa NFLX
# Extraindo dados da empresa AAPL
# Extraindo dados da empresa GOOGL
# Extraindo dados da empresa AMZL
# Extraindo dados da empresa MSFT

# %%
base_alpha_netflix = pd.DataFrame.from_dict([base['Global Quote']])
base_alpha_netflix
# Out:
#   01. symbol 02. open 03. high  04. low 05. price 06. volume  \
# 0       NFLX  92.0500  92.8400  91.3000   91.3700   29707439
#
#   07. latest trading day 08. previous close 09. change 10. change percent
# 0             2026-04-27            92.4400    -1.0700           -1.1575%
